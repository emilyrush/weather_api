# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
import gmaps

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

date = datetime.date.today()
print("Beginning Data Retrieval")
print("-" * 30)
set = 1
count = 1
for city in cities:
    try:
        print(f"Processing Record {count} | {city}")
        query_url = base_url + "appid=" + api_key + "&units=" + units + "&q=" + city
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        
        #Append results to the empty lists
        city_name.append(weather_json['name'])
        cloudiness.append(weather_json['clouds']['all'])
        country.append(weather_json['sys']['country'])
        date.append(datetime.datetime.now())
        humidity.append(weather_json['main']['humidity'])
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        max_temp.append(weather_json['main']['temp_max'])
        wind_speed.append(weather_json['wind']['speed'])
        count += 1
    except KeyError:
        print("City not found. Skipping...")
print("-"*30)
print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 | port alfred
# Processing Record 2 | dikson
# Processing Record 3 | butaritari
# Processing Record 4 | jiddah
# City not found. Skipping...
# Processing Record 4 | qaanaaq
# Processing Record 5 | sharjah
# Processing Record 6 | mar del plata
# Processing Record 7 | barrow
# Processing Record 8 | hermanus
# Processing Record 9 | svetlyy yar
# Processing Record 10 | udayagiri
# Processing Record 11 | kapaa
# Processing Record 12 | vinh
# Processing Record 13 | rikitea
# Processing Record 14 | saleaula
# City not found. Skipping...
# Processing Record 14 | oussouye
# Processing Record 15 | hobart
# Processing Record 16 | nome
# Processing Record 17 | punta arenas
# Processing Record 18 | nouadhibou
# Processing Record 19 | jumla
# Processing Record 20 | laguna
# Processing Record 21 | mount isa
# Processing Record 22 | cidreira
# Processing Record 23 | attawapiskat
# City not found. Skipping...
# Processing Record 23 | khargone
# Processing Record 24 | stornoway
# City not found. Skipping...
# Processing Record 24 | port elizabeth
# Processing Record 25 | norman wells
# Processing Record 26 | castro
# Processing Record 27 | tuktoyaktuk
# Processing Record 28 | lagoa
# Processing Record 29 | san patricio
# Processing Record 30 | umzimvubu
# City not found. Skipping...
# Processing Record 30 | taolanaro
# City not found. Skipping...
# Processing Record 30 | kloulklubed
# Processing Record 31 | lasa
# Processing Record 32 | mega
# Processing Record 33 | graulhet
# Processing Record 34 | saint-philippe
# Processing Record 35 | labuhan
# Processing Record 36 | tasiilaq
# Processing Record 37 | seoul
# Processing Record 38 | nanortalik
# Processing Record 39 | albany
# Processing Record 40 | gat
# Processing Record 41 | atuona
# Processing Record 42 | korla
# City not found. Skipping...
# Processing Record 42 | bredasdorp
# Processing Record 43 | carnarvon
# Processing Record 44 | hithadhoo
# Processing Record 45 | georgetown
# Processing Record 46 | provideniya
# Processing Record 47 | hualmay
# Processing Record 48 | ushuaia
# Processing Record 49 | ayan
# Processing Record 50 | vaini
# Processing Record 51 | puerto escondido
# Processing Record 52 | awjilah
# Processing Record 53 | omsukchan
# Processing Record 54 | avarua
# Processing Record 55 | khed brahma
# Processing Record 56 | mataura
# Processing Record 57 | bandarbeyla
# Processing Record 58 | aasiaat
# Processing Record 59 | zavidovici
# Processing Record 60 | college
# Processing Record 61 | cape town
# Processing Record 62 | bluff
# Processing Record 63 | nichinan
# Processing Record 64 | san felipe
# Processing Record 65 | harlev
# Processing Record 66 | saldanha
# Processing Record 67 | gazanjyk
# Processing Record 68 | chuy
# Processing Record 69 | pevek
# Processing Record 70 | ribeira grande
# Processing Record 71 | jamestown
# Processing Record 72 | yumen
# Processing Record 73 | port lincoln
# Processing Record 74 | buala
# Processing Record 75 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 75 | sao filipe
# Processing Record 76 | chichimila
# Processing Record 77 | saint anthony
# Processing Record 78 | gainesville
# Processing Record 79 | lenger
# Processing Record 80 | petropavlovskoye
# Processing Record 81 | muros
# Processing Record 82 | olafsvik
# City not found. Skipping...
# Processing Record 82 | vila franca do campo
# Processing Record 83 | eyl
# Processing Record 84 | lakatoro
# Processing Record 85 | puerto leguizamo
# Processing Record 86 | kyra
# City not found. Skipping...
# Processing Record 86 | kijang
# Processing Record 87 | iqaluit
# Processing Record 88 | lahij
# Processing Record 89 | husavik
# Processing Record 90 | marsh harbour
# Processing Record 91 | chivay
# Processing Record 92 | malatya
# City not found. Skipping...
# Processing Record 92 | belushya guba
# City not found. Skipping...
# Processing Record 92 | sao luis de montes belos
# Processing Record 93 | gondanglegi
# Processing Record 94 | lebu
# Processing Record 95 | victoria
# Processing Record 96 | praia da vitoria
# Processing Record 97 | hami
# Processing Record 98 | mogadishu
# Processing Record 99 | palmer
# Processing Record 100 | lavrentiya
# Processing Record 101 | shingu
# Processing Record 102 | harwich
# Processing Record 103 | zhangye
# Processing Record 104 | trairi
# Processing Record 105 | amderma
# City not found. Skipping...
# Processing Record 105 | jurado
# City not found. Skipping...
# Processing Record 105 | port hardy
# Processing Record 106 | ankang
# Processing Record 107 | padang
# Processing Record 108 | makakilo city
# Processing Record 109 | maldonado
# Processing Record 110 | nizhneyansk
# City not found. Skipping...
# Processing Record 110 | severo-kurilsk
# Processing Record 111 | upernavik
# Processing Record 112 | vaitupu
# City not found. Skipping...
# Processing Record 112 | amuntai
# Processing Record 113 | puerto ayora
# Processing Record 114 | bengkulu
# City not found. Skipping...
# Processing Record 114 | grand river south east
# City not found. Skipping...
# Processing Record 114 | nieves
# Processing Record 115 | haines junction
# Processing Record 116 | tsihombe
# City not found. Skipping...
# Processing Record 116 | alofi
# Processing Record 117 | maniitsoq
# Processing Record 118 | thomaston
# Processing Record 119 | salalah
# Processing Record 120 | montes altos
# Processing Record 121 | camacha
# Processing Record 122 | hilo
# Processing Record 123 | tuatapere
# Processing Record 124 | berlevag
# Processing Record 125 | aksay
# Processing Record 126 | nador
# Processing Record 127 | cabo san lucas
# Processing Record 128 | new norfolk
# Processing Record 129 | grand gaube
# Processing Record 130 | thompson
# Processing Record 131 | tsaratanana
# Processing Record 132 | magdalena
# Processing Record 133 | narsaq
# Processing Record 134 | santa cruz
# Processing Record 135 | garden city
# Processing Record 136 | sentyabrskiy
# City not found. Skipping...
# Processing Record 136 | bandar
# Processing Record 137 | manono
# Processing Record 138 | pangai
# Processing Record 139 | aloleng
# Processing Record 140 | ponta do sol
# Processing Record 141 | svetlyy
# City not found. Skipping...
# Processing Record 141 | kaitangata
# Processing Record 142 | pangnirtung
# Processing Record 143 | mehran
# Processing Record 144 | khatanga
# Processing Record 145 | kamenskoye
# City not found. Skipping...
# Processing Record 145 | atambua
# Processing Record 146 | longyearbyen
# Processing Record 147 | conakry
# Processing Record 148 | ketchikan
# Processing Record 149 | port-gentil
# Processing Record 150 | gobabis
# Processing Record 151 | meulaboh
# Processing Record 152 | were ilu
# Processing Record 153 | kyshtovka
# Processing Record 154 | buchanan
# Processing Record 155 | mackay
# Processing Record 156 | mantua
# Processing Record 157 | topolovgrad
# Processing Record 158 | nara
# Processing Record 159 | volovo
# Processing Record 160 | saskylakh
# Processing Record 161 | ystad
# Processing Record 162 | tiksi
# Processing Record 163 | merauke
# Processing Record 164 | kattivakkam
# Processing Record 165 | lata
# Processing Record 166 | aksu
# Processing Record 167 | busselton
# Processing Record 168 | nikolskoye
# Processing Record 169 | saint george
# Processing Record 170 | faanui
# Processing Record 171 | borisoglebskiy
# Processing Record 172 | yellowknife
# Processing Record 173 | kyabe
# Processing Record 174 | oranjemund
# Processing Record 175 | zhangzhou
# Processing Record 176 | luderitz
# Processing Record 177 | san luis
# Processing Record 178 | esperance
# Processing Record 179 | pisco
# Processing Record 180 | auki
# Processing Record 181 | ksenyevka
# City not found. Skipping...
# Processing Record 181 | tartus
# City not found. Skipping...
# Processing Record 181 | gurupi
# Processing Record 182 | poindimie
# Processing Record 183 | mys shmidta
# City not found. Skipping...
# Processing Record 183 | lolua
# City not found. Skipping...
# Processing Record 183 | bathsheba
# Processing Record 184 | east london
# Processing Record 185 | graaff-reinet
# Processing Record 186 | mahebourg
# Processing Record 187 | vanimo
# Processing Record 188 | coquimbo
# Processing Record 189 | kangaatsiaq
# Processing Record 190 | kahului
# Processing Record 191 | deputatskiy
# Processing Record 192 | clyde river
# Processing Record 193 | abha
# Processing Record 194 | port hedland
# Processing Record 195 | airai
# Processing Record 196 | bytow
# Processing Record 197 | tumannyy
# City not found. Skipping...
# Processing Record 197 | adrar
# Processing Record 198 | asau
# City not found. Skipping...
# Processing Record 198 | chopda
# Processing Record 199 | vila velha
# Processing Record 200 | marienburg
# Processing Record 201 | severo-yeniseyskiy
# Processing Record 202 | kenai
# Processing Record 203 | arraial do cabo
# Processing Record 204 | noumea
# Processing Record 205 | namibe
# Processing Record 206 | sorland
# Processing Record 207 | zhezkazgan
# Processing Record 208 | uppsala
# Processing Record 209 | torbay
# Processing Record 210 | buta
# Processing Record 211 | potgietersrus
# City not found. Skipping...
# Processing Record 211 | beroroha
# Processing Record 212 | la ronge
# Processing Record 213 | caravelas
# Processing Record 214 | abu dhabi
# Processing Record 215 | taksimo
# Processing Record 216 | loubomo
# City not found. Skipping...
# Processing Record 216 | sao pedro da aldeia
# Processing Record 217 | coihaique
# Processing Record 218 | saint-augustin
# Processing Record 219 | grindavik
# Processing Record 220 | samusu
# City not found. Skipping...
# Processing Record 220 | ginir
# Processing Record 221 | bethel
# Processing Record 222 | champerico
# Processing Record 223 | honningsvag
# Processing Record 224 | luebo
# Processing Record 225 | amudalavalasa
# Processing Record 226 | salamiyah
# Processing Record 227 | vardo
# Processing Record 228 | tabiauea
# City not found. Skipping...
# Processing Record 228 | tual
# Processing Record 229 | tepla
# Processing Record 230 | mandalgovi
# Processing Record 231 | upata
# Processing Record 232 | marcona
# City not found. Skipping...
# Processing Record 232 | lompoc
# Processing Record 233 | zhovtneve
# City not found. Skipping...
# Processing Record 233 | tomatlan
# Processing Record 234 | herat
# Processing Record 235 | muravlenko
# Processing Record 236 | chokurdakh
# Processing Record 237 | los llanos de aridane
# Processing Record 238 | custoias
# Processing Record 239 | mount gambier
# Processing Record 240 | kodiak
# Processing Record 241 | portland
# Processing Record 242 | ahipara
# Processing Record 243 | hukuntsi
# Processing Record 244 | asahikawa
# Processing Record 245 | sunbury
# Processing Record 246 | ngorongoro
# Processing Record 247 | tiznit
# Processing Record 248 | nemuro
# Processing Record 249 | puerto colombia
# Processing Record 250 | kikwit
# Processing Record 251 | faya
# Processing Record 252 | willowmore
# Processing Record 253 | sampit
# Processing Record 254 | roma
# Processing Record 255 | wahran
# City not found. Skipping...
# Processing Record 255 | avera
# Processing Record 256 | hirara
# Processing Record 257 | kybartai
# Processing Record 258 | olinda
# Processing Record 259 | mayskiy
# Processing Record 260 | muli
# Processing Record 261 | jawhar
# Processing Record 262 | ilulissat
# Processing Record 263 | alberton
# Processing Record 264 | valparaiso
# Processing Record 265 | funadhoo
# Processing Record 266 | soyo
# Processing Record 267 | atripalda
# Processing Record 268 | whakatane
# Processing Record 269 | mahanje
# City not found. Skipping...
# Processing Record 269 | erzurum
# Processing Record 270 | bambanglipuro
# Processing Record 271 | paraiso
# Processing Record 272 | asosa
# Processing Record 273 | tezu
# Processing Record 274 | san jose
# Processing Record 275 | bubaque
# Processing Record 276 | traverse city
# Processing Record 277 | do gonbadan
# Processing Record 278 | sarangani
# Processing Record 279 | porbandar
# Processing Record 280 | saryozek
# Processing Record 281 | novoseleznevo
# Processing Record 282 | balkhash
# Processing Record 283 | port blair
# Processing Record 284 | camocim
# Processing Record 285 | karpathos
# Processing Record 286 | port augusta
# Processing Record 287 | hauterive
# Processing Record 288 | torres
# Processing Record 289 | payson
# Processing Record 290 | derzhavinsk
# Processing Record 291 | zhenlai
# Processing Record 292 | altamira
# Processing Record 293 | zyryanovsk
# Processing Record 294 | nuuk
# Processing Record 295 | pascagoula
# Processing Record 296 | moose factory
# Processing Record 297 | sao gabriel
# Processing Record 298 | san andres
# Processing Record 299 | paamiut
# Processing Record 300 | vostok
# Processing Record 301 | maraa
# Processing Record 302 | ballina
# Processing Record 303 | uttaradit
# Processing Record 304 | turayf
# Processing Record 305 | codrington
# Processing Record 306 | bambous virieux
# Processing Record 307 | souillac
# Processing Record 308 | greenville
# Processing Record 309 | zainsk
# Processing Record 310 | snezhnogorsk
# Processing Record 311 | junction city
# Processing Record 312 | matay
# Processing Record 313 | zverinogolovskoye
# Processing Record 314 | makat
# Processing Record 315 | tarnogskiy gorodok
# Processing Record 316 | brewster
# Processing Record 317 | broken hill
# Processing Record 318 | havre-saint-pierre
# Processing Record 319 | lewistown
# Processing Record 320 | kudahuvadhoo
# Processing Record 321 | dese
# Processing Record 322 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 322 | mukhen
# Processing Record 323 | owando
# Processing Record 324 | loiza
# Processing Record 325 | neuchatel
# City not found. Skipping...
# Processing Record 325 | abu kamal
# Processing Record 326 | hambantota
# Processing Record 327 | rorvik
# Processing Record 328 | tecoanapa
# Processing Record 329 | shelburne
# Processing Record 330 | sao joao da barra
# Processing Record 331 | waconia
# Processing Record 332 | batagay
# Processing Record 333 | samarai
# Processing Record 334 | half moon bay
# Processing Record 335 | ismailia
# Processing Record 336 | sitka
# Processing Record 337 | bintulu
# Processing Record 338 | solnechnyy
# Processing Record 339 | kitaibaraki
# Processing Record 340 | dolbeau
# City not found. Skipping...
# Processing Record 340 | klaksvik
# Processing Record 341 | muyezerskiy
# Processing Record 342 | lethem
# Processing Record 343 | youkounkoun
# Processing Record 344 | mikkeli
# Processing Record 345 | guerrero negro
# Processing Record 346 | sivaki
# Processing Record 347 | barawe
# City not found. Skipping...
# Processing Record 347 | rawannawi
# City not found. Skipping...
# Processing Record 347 | mahenge
# Processing Record 348 | ewa beach
# Processing Record 349 | biak
# Processing Record 350 | bajo baudo
# City not found. Skipping...
# Processing Record 350 | staraya kulatka
# Processing Record 351 | placido de castro
# Processing Record 352 | kontagora
# Processing Record 353 | marshfield
# Processing Record 354 | canaries
# City not found. Skipping...
# Processing Record 354 | sahy
# Processing Record 355 | pemangkat
# City not found. Skipping...
# Processing Record 355 | barentsburg
# City not found. Skipping...
# Processing Record 355 | ambilobe
# Processing Record 356 | benguela
# Processing Record 357 | dandong
# Processing Record 358 | te anau
# Processing Record 359 | daru
# Processing Record 360 | talnakh
# Processing Record 361 | komsomolskiy
# Processing Record 362 | rosarito
# Processing Record 363 | stulovo
# Processing Record 364 | batsfjord
# Processing Record 365 | pucara
# Processing Record 366 | sawtell
# Processing Record 367 | mehriz
# Processing Record 368 | aswan
# Processing Record 369 | the valley
# Processing Record 370 | satitoa
# City not found. Skipping...
# Processing Record 370 | ancud
# Processing Record 371 | leshukonskoye
# Processing Record 372 | uyemskiy
# Processing Record 373 | tukrah
# City not found. Skipping...
# Processing Record 373 | todos santos
# Processing Record 374 | hornepayne
# Processing Record 375 | kayes
# Processing Record 376 | vila do maio
# Processing Record 377 | mullaitivu
# City not found. Skipping...
# Processing Record 377 | havoysund
# Processing Record 378 | fairlie
# Processing Record 379 | elat
# Processing Record 380 | vao
# Processing Record 381 | tigzirt
# Processing Record 382 | vila
# Processing Record 383 | constitucion
# Processing Record 384 | manga
# Processing Record 385 | hernani
# Processing Record 386 | yuanping
# Processing Record 387 | santiago
# Processing Record 388 | truckee
# Processing Record 389 | poddorye
# Processing Record 390 | agadir
# Processing Record 391 | hasaki
# Processing Record 392 | kavieng
# Processing Record 393 | skala
# Processing Record 394 | kruisfontein
# Processing Record 395 | acapulco
# Processing Record 396 | cheyenne
# Processing Record 397 | wajima
# Processing Record 398 | mecca
# Processing Record 399 | voronezhskaya
# Processing Record 400 | dalton
# Processing Record 401 | egvekinot
# Processing Record 402 | salmas
# Processing Record 403 | springfield
# Processing Record 404 | touros
# Processing Record 405 | awbari
# Processing Record 406 | flinders
# Processing Record 407 | rawson
# Processing Record 408 | berdigestyakh
# Processing Record 409 | birjand
# Processing Record 410 | yanan
# City not found. Skipping...
# Processing Record 410 | geraldton
# Processing Record 411 | bairiki
# City not found. Skipping...
# Processing Record 411 | aguililla
# Processing Record 412 | pringsewu
# Processing Record 413 | mendoza
# Processing Record 414 | kupang
# Processing Record 415 | yairipok
# Processing Record 416 | kavaratti
# Processing Record 417 | naze
# Processing Record 418 | angoche
# Processing Record 419 | cherskiy
# Processing Record 420 | santa cruz del sur
# Processing Record 421 | karauzyak
# City not found. Skipping...
# Processing Record 421 | gorontalo
# Processing Record 422 | majene
# Processing Record 423 | makuyuni
# Processing Record 424 | saint-pierre
# Processing Record 425 | lufkin
# Processing Record 426 | sisimiut
# Processing Record 427 | nhulunbuy
# Processing Record 428 | waipawa
# Processing Record 429 | penzance
# Processing Record 430 | benghazi
# Processing Record 431 | alyangula
# Processing Record 432 | usinsk
# Processing Record 433 | williams lake
# Processing Record 434 | tarko-sale
# Processing Record 435 | umm lajj
# Processing Record 436 | yvetot
# Processing Record 437 | kolaras
# Processing Record 438 | buin
# Processing Record 439 | atar
# Processing Record 440 | srednekolymsk
# Processing Record 441 | shimanovsk
# Processing Record 442 | brindisi
# Processing Record 443 | toliary
# City not found. Skipping...
# Processing Record 443 | caibarien
# Processing Record 444 | le portel
# Processing Record 445 | morondava
# Processing Record 446 | guajara
# Processing Record 447 | albesti
# Processing Record 448 | saint-francois
# Processing Record 449 | leningradskiy
# Processing Record 450 | palestine
# Processing Record 451 | sobolevo
# Processing Record 452 | beringovskiy
# Processing Record 453 | kamenka
# Processing Record 454 | chapais
# Processing Record 455 | salinas
# Processing Record 456 | golyshmanovo
# Processing Record 457 | adre
# Processing Record 458 | campbellton
# Processing Record 459 | skalistyy
# City not found. Skipping...
# Processing Record 459 | santo domingo
# Processing Record 460 | jaipur hat
# City not found. Skipping...
# Processing Record 460 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 460 | maykain
# City not found. Skipping...
# Processing Record 460 | midyat
# Processing Record 461 | tautira
# Processing Record 462 | neryungri
# Processing Record 463 | fairbanks
# Processing Record 464 | babra
# Processing Record 465 | north bend
# Processing Record 466 | sola
# Processing Record 467 | basco
# Processing Record 468 | turka
# Processing Record 469 | uray
# Processing Record 470 | fallon
# Processing Record 471 | bone
# Processing Record 472 | mutsu
# Processing Record 473 | huaidian
# City not found. Skipping...
# Processing Record 473 | george
# Processing Record 474 | sao francisco de assis
# City not found. Skipping...
# Processing Record 474 | yaan
# Processing Record 475 | karaul
# City not found. Skipping...
# Processing Record 475 | kathmandu
# Processing Record 476 | presidente medici
# Processing Record 477 | rio grande
# Processing Record 478 | burica
# City not found. Skipping...
# Processing Record 478 | kapit
# Processing Record 479 | bom jesus
# Processing Record 480 | mackenzie
# Processing Record 481 | santa fe
# Processing Record 482 | jawa
# Processing Record 483 | alice springs
# Processing Record 484 | utete
# Processing Record 485 | tibiao
# Processing Record 486 | tilichiki
# Processing Record 487 | moree
# Processing Record 488 | gaoual
# Processing Record 489 | kasane
# Processing Record 490 | mouzakion
# City not found. Skipping...
# Processing Record 490 | amahai
# Processing Record 491 | safwah
# City not found. Skipping...
# Processing Record 491 | setermoen
# Processing Record 492 | fortuna
# Processing Record 493 | luwingu
# Processing Record 494 | alekseyevka
# Processing Record 495 | riyadh
# Processing Record 496 | krasnovka
# Processing Record 497 | hay river
# Processing Record 498 | sharanga
# Processing Record 499 | rongcheng
# Processing Record 500 | yerbogachen
# Processing Record 501 | gornyatskiy
# Processing Record 502 | christchurch
# Processing Record 503 | hofn
# Processing Record 504 | meiganga
# Processing Record 505 | huilong
# Processing Record 506 | florida
# Processing Record 507 | russell
# Processing Record 508 | sarakhs
# Processing Record 509 | sur
# Processing Record 510 | ardon
# Processing Record 511 | hamilton
# Processing Record 512 | balabac
# Processing Record 513 | san francisco
# Processing Record 514 | troitsko-pechorsk
# Processing Record 515 | sioux lookout
# Processing Record 516 | junin
# Processing Record 517 | ihosy
# Processing Record 518 | osoyoos
# Processing Record 519 | svetlogorsk
# Processing Record 520 | teocaltiche
# Processing Record 521 | garut
# Processing Record 522 | sakakah
# City not found. Skipping...
# Processing Record 522 | asyut
# Processing Record 523 | mossendjo
# Processing Record 524 | diffa
# Processing Record 525 | winnemucca
# Processing Record 526 | paola
# Processing Record 527 | scarborough
# Processing Record 528 | kaeo
# Processing Record 529 | tapaua
# City not found. Skipping...
# Processing Record 529 | west odessa
# Processing Record 530 | kushmurun
# City not found. Skipping...
# Processing Record 530 | marakkanam
# Processing Record 531 | gerede
# Processing Record 532 | chimbote
# Processing Record 533 | nelson bay
# Processing Record 534 | umba
# Processing Record 535 | razole
# Processing Record 536 | polkowice
# Processing Record 537 | itarema
# Processing Record 538 | palmares do sul
# Processing Record 539 | terrasini
# Processing Record 540 | tucuman
# Processing Record 541 | malibu
# Processing Record 542 | cham
# Processing Record 543 | taoudenni
# Processing Record 544 | puerto carreno
# Processing Record 545 | muroto
# Processing Record 546 | ovalle
# Processing Record 547 | aleksandrov gay
# Processing Record 548 | wanlaweyn
# ------------------------------
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = pd.DataFrame({'City': city_name,
                          'Cloudiness': cloudiness,
                          'Country': country,
                          'Date': date,
                          'Humidity': humidity,
                          'Latitude': lat,
                          'Longitude': lng,
                          'Max Temp': max_temp,
                          'Wind Speed': wind_speed
                         })
cities_df.head()
cities_df.to_csv("city_temps.csv", encoding="utf-8", index=False)

# %%
cities_df.count()
# Out:
# City          567
# Cloudiness    567
# Country       567
# Date          567
# Humidity      567
# Latitude      567
# Longitude     567
# Max Temp      567
# Wind Speed    567
# dtype: int64

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
cities_df.head()
# Out:
#           City  Cloudiness Country                       Date  Humidity  \
# 0  Port Alfred           0      ZA 2019-01-13 12:19:50.300192        79
# 1       Dikson          80      RU 2019-01-13 12:19:50.464605        92
# 2   Butaritari          64      KI 2019-01-13 12:19:50.664618       100
# 3      Qaanaaq           0      GL 2019-01-13 12:19:50.781117        78
# 4      Sharjah           0      AE 2019-01-13 12:19:50.940970        49
#
#    Latitude  Longitude  Max Temp  Wind Speed
# 0    -33.59      26.89     70.48       12.77
# 1     73.51      80.55      1.00       31.12
# 2      3.07     172.79     81.86       15.12
# 3     77.48     -69.36    -25.96        9.98
# 4     25.36      55.39     73.40        8.05

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, max_temp, marker="o", c=max_temp, cmap="jet", alpha=0.75)

plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title(f"City Latitude vs. Max Temperature ({date})")
plt.grid(True)
plt.show
# Out:
# 2019-01-13

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, marker="o", c=humidity, cmap="Blues", edgecolors="darkblue", alpha=0.75)
date = datetime.today()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-0fb70bbbec48> in <module>()
#       1 plt.scatter(lat, humidity, marker="o", c=humidity, cmap="Blues", edgecolors="darkblue", alpha=0.75)
# ----> 2 date = datetime.today()
#       3 plt.xlabel("Latitude")
#       4 plt.ylabel("Humidity")
#       5 plt.title(f"City Latitude vs. Humidity ({date})")
#
# AttributeError: module 'datetime' has no attribute 'today'

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloudiness, marker="o", c=cloudiness, s=cloudiness*5, cmap="bone_r", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.axvline(x=0,color="red")

plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True)


# # Incorporate a text label regarding circle size
plt.text(90,50, "Note: Circle size \ncorrelates with \ncloudiness", ha="left", va="top")

# Save Figure
# plt.savefig("Images/cloudiness_bubble_plot.png", bbox_inches="tight")
# Out:
# Text(90, 50, 'Note: Circle size \ncorrelates with \ncloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind_speed, marker=6, c=wind_speed, cmap="winter_r", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True)

# %%
locations = cities_df[['Latitude', 'Longitude']].astype(float)
humid = cities_df['Humidity'].astype(float)


center=(0.0,0.0)
fig = gmaps.figure(center=center, zoom_level=1)

heat_layer = gmaps.heatmap_layer(locations, weights=humid, dissipating=False, max_intensity=100, point_radius=4)


fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = cities_df[['Latitude', 'Longitude']].astype(float)
clouds = cities_df['Cloudiness'].astype(float)

center=(0.0,0.0)
fig = gmaps.figure(center=center, zoom_level=1)

heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=50, point_radius=4)
heat_layer.gradient = [(0,0,0,0), (128,128,128,1),(105,105,105,1)]

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Out:
# '2019-01-13 00:54:23.633294'
